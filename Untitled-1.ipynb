# %%
from fpdf import FPDF

# Replace special characters to avoid encoding issues
content = """
Python-for-ML Crash Course (2-Week Plan)

Week 1 - Python Basics & Data Handling

Day 1: Python Setup & Basics
- Install Python/Anaconda/VS Code or use Google Colab
- Variables, numbers, strings
- Print statements and comments
- Hands-on: Print a sentence, create 3 variables and do arithmetic
- YouTube: Programming with Mosh - Python for Beginners

Day 2: Lists & Loops
- Lists, indexing, slicing
- For-loops, while-loops
- Hands-on: Loop through a list and print squares of numbers

Day 3: Dictionaries & Conditions
- Dictionaries (key-value)
- If / elif / else statements
- Hands-on: Create a dictionary of 3 students with grades; print names with grade > 80

Day 4: Functions
- Define functions (def)
- Return values and parameters
- Hands-on: Write a function to calculate square and cube of a number

Day 5: Importing Modules
- import math, import random
- Use math.sqrt, random.randint
- Hands-on: Generate 5 random numbers and calculate their square roots

Weekend Mini Project:
- Load a CSV file (Iris/Titanic)
- Print first 5 rows
- Select one column and calculate mean/max/min
- Tools: Pandas
- YouTube: Corey Schafer - Pandas playlist

Week 2 - Python for Data & ML

Day 6: NumPy Basics
- Arrays, shape, indexing
- Basic operations (+, -, *, /)
- Hands-on: Create an array of 10 numbers, calculate sum, mean, max
- YouTube: Krish Naik - NumPy tutorials

Day 7: Pandas Basics
- Series & DataFrames
- Reading CSV
- Selecting rows/columns
- Hands-on: Read Iris dataset; select species column; filter rows where sepal length > 5

Day 8: Data Cleaning
- Handle missing values (isnull(), dropna(), fillna())
- Hands-on: Load dataset with missing values; fill missing numerical values with mean

Day 9: Basic Plotting
- matplotlib / seaborn basics
- Plot histogram, scatter plot
- Hands-on: Plot sepal length vs petal length (Iris dataset)

Day 10: Python for ML (scikit-learn)
- Train/Test split
- Import model (DecisionTreeClassifier)
- Fit and predict
- Hands-on code example:
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target)
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print(predictions)

Weekend Mini Project:
- Goal: Train a simple classifier
  - Load Iris/Titanic dataset
  - Clean data
  - Split into train/test
  - Train a Decision Tree
  - Evaluate accuracy
- Outcome: Hands-on Python + ML workflow ready for Azure ML notebooks

Optional Resources:
- YouTube: Corey Schafer (Python + Pandas), Krish Naik (NumPy + ML)
- Udemy: Python for Data Science & ML Bootcamp (focus on Python + Pandas + Scikit-learn)

Tips:
- Don't memorize syntax; focus on patterns: Load data -> Clean -> Split -> Train -> Predict -> Evaluate
- Once you can do this, Azure ML becomes much easier
"""

# Create PDF
pdf = FPDF()
pdf.set_auto_page_break(auto=True, margin=15)
pdf.add_page()
pdf.set_font("helvetica", 'B', 16)
pdf.cell(0, 10, "Python-for-ML Crash Course (2-Week Plan)", ln=True)
pdf.set_font("helvetica", '', 12)
pdf.multi_cell(0, 8, content)

# Save PDF
pdf_file_path = "/mnt/data/Python_for_ML_Crash_Course.pdf"
pdf.output(pdf_file_path)
pdf_file_path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from fpdf import FPDF
#       3 # Replace special characters to avoid encoding issues
#       4 content = """
#       5 Python-for-ML Crash Course (2-Week Plan)
#       6
#    (...)     97 - Once you can do this, Azure ML becomes much easier
#      98 """
#
# ModuleNotFoundError: No module named 'fpdf'
