# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramjeet-Dixit/IITM-AIML-Rdixit/blob/main/tsne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **t-Distributed Stochastic Neighbor Embedding**
#
# t-SNE (t-Distributed Stochastic Neighbor Embedding) is a popular technique for dimensionality reduction that is particularly well suited for the visualization of high-dimensional datasets.
#
# It converts similarities between data points to joint probabilities and tries to minimize the Kullback-Leibler divergence between the joint probabilities of the low-dimensional embedding and the high-dimensional data.

# %%
import numpy as np #array data
import pandas as pd #dataframes
import matplotlib.pyplot as plt #visualizations
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler #scaling the data

# %%
from sklearn.datasets import load_iris

# Load the dataset
iris = load_iris()
type(iris)
# Out:
# sklearn.utils._bunch.Bunch

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
X = iris.data
y = iris.target

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
tsne = TSNE(n_components=2, perplexity=30, learning_rate=100, init = "pca", random_state=42) #n_iter #early exaggerations #init
X_tsne = tsne.fit_transform(X_scaled)

#perplexity < n_samples / 3.
# auto learning rate -- n_samples / early_exaggeration / 4

# %%
X_tsne
# Out:
# array([[ 19.482656 ,  15.812173 ],
#        [ 15.822896 ,  14.542083 ],
#        [ 17.233032 ,  14.16349  ],
#        [ 16.581425 ,  13.732751 ],
#        [ 20.195887 ,  15.578113 ],
#        [ 21.615168 ,  16.812046 ],
#        [ 18.499054 ,  14.013842 ],
#        [ 18.624588 ,  15.293515 ],
#        [ 15.557208 ,  13.406668 ],
#        [ 16.494492 ,  14.816165 ],
#        [ 20.600092 ,  16.841753 ],
#        [ 18.58412  ,  14.61195  ],
#        [ 15.904258 ,  14.120466 ],
#        [ 16.160246 ,  13.0302105],
#        [ 21.82663  ,  17.570042 ],
#        [ 22.59457  ,  17.417608 ],
#        [ 21.56716  ,  16.900484 ],
#        [ 19.48038  ,  15.759997 ],
#        [ 21.12036  ,  17.411217 ],
#        [ 21.254051 ,  16.087755 ],
#        [ 18.828913 ,  16.6771   ],
#        [ 20.735487 ,  15.892169 ],
#        [ 20.114079 ,  14.3413925],
#        [ 17.860079 ,  15.868421 ],
#        [ 18.60464  ,  14.54925  ],
#        [ 15.885354 ,  14.901052 ],
#        [ 18.683392 ,  15.295633 ],
# ...

# %%
np.unique(y)
# Out:
# array([0, 1, 2])

# %% [markdown]
# perplexity < n_samples / 3.

# %%
plt.figure(figsize=(10, 6))
for i in np.unique(y):
    plt.scatter(X_tsne[y == i, 0], X_tsne[y == i, 1], label=iris.target_names[i])
plt.legend()
plt.title('t-SNE Visualization of Iris Dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %% [markdown]
# Benefits of t-SNE
#
# Visualization: t-SNE is particularly effective for visualizing high-dimensional data in 2 or 3 dimensions. It helps in understanding the structure and distribution of the data.
#
# Clustering: t-SNE can reveal clusters in the data, which can be useful for identifying groups or patterns that are not immediately obvious in higher-dimensional space.
#
# Non-Linear Relationships: Unlike PCA, which is a linear dimensionality reduction method, t-SNE can capture non-linear relationships between data points, providing more meaningful embeddings for complex datasets.

# %% [markdown]
# **Interpretation of t-SNE Results**
#
# Interpreting t-SNE results involves looking at the clusters and their separations:
#
# **Clusters:** Points that are grouped together in the t-SNE plot are likely to be similar in the high-dimensional space. For example, in the Iris dataset, you might see clear clusters corresponding to different species of flowers.
#
# **Distances:** The distances between clusters can give insights into the relationships between different groups. Clusters that are far apart indicate distinct groups, while those that are close may suggest some overlap or similarity.
#
# **Shape and Spread**: The shape and spread of the clusters can also provide information about the variability within each group. Tight clusters suggest low variability, while spread-out clusters indicate higher variability.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

# Load the dataset
wine = load_wine()
X = wine.data

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply t-SNE
tsne = TSNE(n_components=2, perplexity=30, learning_rate=200, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

X_tsne
# Out:
# array([[ 11.526138  ,   6.2860036 ],
#        [  8.186278  ,   4.909773  ],
#        [  7.774753  ,   9.096497  ],
#        [ 10.718241  ,   9.076212  ],
#        [  3.738565  ,   7.848719  ],
#        [  9.972226  ,   9.495651  ],
#        [  8.287591  ,   6.9030504 ],
#        [  5.528957  ,   8.584971  ],
#        [  8.9337845 ,   6.7979045 ],
#        [  9.632934  ,   7.1660113 ],
#        [  8.947561  ,   9.726274  ],
#        [  7.470224  ,   6.575292  ],
#        [  7.6298885 ,   7.1741395 ],
#        [ 11.437133  ,  10.519758  ],
#        [ 11.090027  ,  10.277111  ],
#        [  6.2735977 ,   8.968899  ],
#        [  6.475424  ,   9.84567   ],
#        [  6.121908  ,   9.692361  ],
#        [  9.723453  ,  10.308382  ],
#        [ 10.29154   ,   4.538904  ],
#        [ 11.3110075 ,   6.133065  ],
#        [  6.26999   ,   3.4154317 ],
#        [  7.726496  ,   5.8655124 ],
#        [  5.859617  ,   5.4298167 ],
#        [  5.449825  ,   5.4791946 ],
# ...

# %%
# Visualize the results
plt.figure(figsize=(10, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c='blue', alpha=0.5)
plt.title('t-SNE Visualization of Wine Dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
