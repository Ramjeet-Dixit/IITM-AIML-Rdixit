# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramjeet-Dixit/IITM-AIML-Rdixit/blob/main/Bodhak_Data_Visualization_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BAR PLOT
#
# gives you the frequency on the y axis
#
# x axis should ideally be categorical in nature

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

Movie_type = ['Comedy','Action','Romance','Drama','Scifi']#x axis

Responses = [4,5,6,1,4]#y axis

ax.bar(Movie_type, Responses)

ax.set_ylabel("Survey Responses")

ax.set_xlabel("Movie_Type")

ax.set_title("MOVIES")

ax.set_xticklabels(Movie_type, rotation=30)

plt.show()
# Out:
# /var/folders/fr/5_6br7tn5_j9cl4dbzgztk0c0000gn/T/ipykernel_4438/3136750503.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(Movie_type, rotation=30)

# %%
import matplotlib.pyplot as plt
import statistics

fig, ax = plt.subplots()

Movie_type = ['Comedy','Action','Romance','Drama','Scifi']

Responses = [4,5,6,1,4]

ax.bar(Movie_type, Responses)

ax.set_ylabel("Survey Responses")

fig.savefig("/Users/ramjeetdixit/Documents/Movie_Responses.png", dpi=300) #sharing and saving figures

fig.set_size_inches([8, 5]) #setting size of plot

plt.show()

# %%
statistics.stdev(Responses)
# Out:
# 1.8708286933869707

# %%
import matplotlib.pyplot as plt
import statistics

fig, ax = plt.subplots()

Movie_type = ['Comedy','Action','Romance','Drama','Scifi']

Responses = [4,5,6,1,4]

Responses_std = statistics.stdev(Responses)

ax.bar(Movie_type, Responses,yerr=Responses_std)

ax.set_ylabel("Survey Responses")

plt.show()

# %%
#plotting multiple data
import matplotlib.pyplot as plt

Movie_type = ['Comedy','Action','Romance','Drama','Scifi']

Men_responses = [4,5,6,1,4]

Women_responses = [8, 2, 7, 2, 1]

fig, ax = plt.subplots()

ax.bar(Movie_type, Men_responses, color = 'b', width = 0.50, label="Men Response")

ax.bar(Movie_type, Women_responses, color = 'g', width = 0.25, label="Women Response")

ax.set_ylabel("Survey Responses")

ax.legend()

ax.set_xticklabels(Movie_type, rotation=45)

plt.show()
# Out:
# /var/folders/fr/5_6br7tn5_j9cl4dbzgztk0c0000gn/T/ipykernel_4438/815350357.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(Movie_type, rotation=45)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
Movie_type = ['Comedy', 'Action', 'Romance', 'Drama', 'Scifi']
Men_responses = [4, 5, 6, 1, 4]
Women_responses = [8, 2, 7, 2, 1]

# Positions for side-by-side bars
x = np.arange(len(Movie_type))
width = 0.35

# Plot
plt.figure()
plt.bar(x - width/2, Men_responses, width, label='Men Response')
plt.bar(x + width/2, Women_responses, width, label='Women Response')

# Labels and formatting
plt.ylabel('Survey Responses')
plt.xticks(x, Movie_type, rotation=45)
plt.legend()
plt.tight_layout()

# Display the plot
plt.show()

# %%
#Stacked bar chart
import matplotlib.pyplot as plt
Movie_type = ['Comedy','Action','Romance','Drama','Scifi']

Men_responses = [4,5,6,1,4]

Women_responses = [8, 2, 7, 2, 1]


fig, ax = plt.subplots()

ax.bar(Movie_type, Men_responses, color = 'b')

ax.bar(Movie_type, Women_responses, bottom = Men_responses, color = 'r')


ax.set_ylabel("Survey Responses")
ax.set_xticklabels(Movie_type, rotation=45)

ax.legend(labels=['Men', 'Women'])

plt.show()
# Out:
# /var/folders/fr/5_6br7tn5_j9cl4dbzgztk0c0000gn/T/ipykernel_4438/719751332.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(Movie_type, rotation=45)

# %% [markdown]
# ### BOX PLOT

# %% [markdown]
# 2,::5::,7 --Q1: 25th percentile
#
# --8-- Q2
#
# 9,::10::,12 -- Q3
#
# 2,5
#
# 5 to 8 and 8 to 10
#
# 10 to 12
#
#
# 1 to 25: lowest 25 items
#
# 25 to 50 and 50 to 75
#
# 75 to 100 highest 25 items
#
# median is also referred to as quartile 2: Q2: 50th percentile

# %%
import numpy as np

collectn_1 = np.random.normal(100, 10, 200)
print(collectn_1)
# Out:
# [ 97.52474334  95.38904208 101.63593    100.33719952 105.14551195
#   92.54923244  94.89995672 101.38195509 107.5418812   94.85407704
#   81.2211747   95.53038375 105.87150292 116.44700899  99.983472
#  104.42735247  95.48961606  92.00986642  92.12973063 102.29895336
#  110.63827421 113.89047424 102.7979413   95.13895832 111.0907202
#  105.7642534   91.84145404 109.9920973  103.58457739 108.40274312
#   93.58543051 104.81817747 104.90520329  95.14637056  96.28706989
#   89.78638792 101.9200414   84.0569465  101.04884505 107.43351116
#  103.52084151 120.04815766  94.73081082 104.2807367  104.0193738
#   86.1619872  117.20218313 104.88062049  80.77149313  92.89213677
#  113.66857873 108.91472279  73.51086198  95.75962839  89.96478558
#   92.45609863 114.49134378 113.77875613  91.21254802  97.75382371
#   87.01744728  97.00610046  98.66103196  97.71167413  90.11295555
#   98.88993607  83.00233983  89.18710219  95.10963677 110.63127183
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(10)
collectn_1 = np.random.normal(100, 10, 200)
collectn_2 = np.random.normal(80, 30, 200)
collectn_3 = np.random.normal(90, 20, 200)
collectn_4 = np.random.normal(70, 25, 200)
#It takes three arguments, mean and standard deviation of the normal distribution, and the number of values desired.

## combine these different collections into a list
data_to_plot = [collectn_1, collectn_2, collectn_3, collectn_4]

fig, ax = plt.subplots()

# Create the boxplot
ax.boxplot(data_to_plot)

plt.show()

# %%
import numpy as np
np.random.seed(10)
collectn_1 = np.random.normal(100, 10, 200)
collectn_2 = np.random.normal(80, 30, 200)
collectn_3 = np.random.normal(90, 20, 200)
collectn_4 = np.random.normal(70, 25, 200)
#It takes three arguments, mean and standard deviation of the normal distribution, and the number of values desired.

## combine these different collections into a list
data_to_plot = [collectn_1, collectn_2, collectn_3, collectn_4]

fig, ax = plt.subplots()

# Create the boxplot
bp = ax.violinplot(data_to_plot)

plt.show()

# %%
x = np.random.normal(170, 10, 250)
x
# Out:
# array([170.21043221, 171.56371522, 180.3765419 , 170.456659  ,
#        181.07336149, 156.62210949, 167.46333278, 182.5487984 ,
#        169.19454832, 157.79157745, 158.44073915, 162.42660148,
#        156.87608593, 174.95348507, 141.84938692, 161.78621698,
#        156.0934942 , 156.26757327, 164.30448307, 157.65066623,
#        174.7759765 , 162.1052086 , 164.47764723, 178.3763692 ,
#        172.72717817, 171.26255476, 169.74141578, 158.7565778 ,
#        173.01572789, 191.18591436, 167.37033863, 159.96612056,
#        154.82203775, 150.78005096, 166.56654751, 164.59635669,
#        180.45169505, 169.20064763, 176.61394965, 176.23388411,
#        181.98601831, 166.91219186, 179.70167989, 174.51046213,
#        159.37293279, 159.74857963, 174.19614024, 166.8466772 ,
#        147.89245588, 172.56789835, 172.60529355, 171.98179914,
#        185.2585204 , 166.01727746, 154.63604791, 176.34149065,
#        171.54902806, 176.00676777, 176.47285486, 171.49564405,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)
#histogram will convert your data into class intervals: x axis
#y axis will show the frequency
#univariate plot

plt.hist(x, bins=10, histtype="stepfilled")#bins represent class interval
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x, bins=[140,150,160,170,180,190,200], histtype="stepfilled")

plt.show()

# %%
#scatter plot:
import matplotlib.pyplot as plt

girls_grades = [89, 90, 70, 89, 100, 80, 90, 100, 80, 34]

boys_grades = [30, 29, 49, 48, 100, 48, 38, 45, 20, 30]


fig, ax = plt.subplots()

ax.scatter(girls_grades, boys_grades, color='b',label="Grades")

ax.legend()

ax.set_xlabel('girlsgrade')
ax.set_ylabel('boys grade')
ax.set_title('scatter plot')

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
