# %%
from sklearn.datasets import fetch_california_housing

data = fetch_california_housing(as_frame=True)
df=data.frame
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_csv("california_housing.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.to_csv("california_housing.csv", index=False)
#
# File ~/MyEnv/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/MyEnv/lib/python3.11/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)   3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/MyEnv/lib/python3.11/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/MyEnv/lib/python3.11/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/MyEnv/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 30] Read-only file system: 'california_housing.csv'

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# !pip install tensorflow-macos
# !pip install tensorflow-metal
import tensorflow as tf
from tensorflow.keras import layers, Model

# For reproducibility
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# Collecting tensorflow-macos
#   Downloading tensorflow_macos-2.16.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting tensorflow==2.16.2 (from tensorflow-macos)
#   Downloading tensorflow-2.16.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (18.1.1)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.16.2->tensorflow-macos)
#   Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.4.0)
# Requirement already satisfied: packaging in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow==2.16.2->tensorflow-macos)
#   Downloading protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.32.3)
# Requirement already satisfied: setuptools in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (80.7.1)
# Requirement already satisfied: six>=1.12.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.71.0)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.2->tensorflow-macos)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.0.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow==2.16.2->tensorflow-macos) (0.45.1)
# Requirement already satisfied: rich in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (14.0.0)
# Requirement already satisfied: namex in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.0.9)
# Requirement already satisfied: optree in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.1.2)
# Downloading tensorflow_macos-2.16.2-cp311-cp311-macosx_12_0_arm64.whl (2.1 kB)
# Downloading tensorflow-2.16.2-cp311-cp311-macosx_12_0_arm64.whl (227.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 MB 25.7 MB/s  0:00:08m0:00:0100:01
# Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl (389 kB)
# Downloading protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 26.6 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: protobuf, ml-dtypes, tensorboard, tensorflow, tensorflow-macos
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: ml-dtypes━━━━━━━━━━━━━━━ 0/5 [protobuf]
#     Found existing installation: ml_dtypes 0.5.1 0/5 [protobuf]
#     Uninstalling ml_dtypes-0.5.1:━━━━━━━━━━━ 0/5 [protobuf]
#       Successfully uninstalled ml_dtypes-0.5.10m 0/5 [protobuf]
#   Attempting uninstall: tensorboard━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/5 [ml-dtypes]
#     Found existing installation: tensorboard 2.19.0━━━━━━━━━━━ 1/5 [ml-dtypes]
#     Uninstalling tensorboard-2.19.0:━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/5 [ml-dtypes]
#       Successfully uninstalled tensorboard-2.19.0━━━━━━━━━━━━━ 1/5 [ml-dtypes]
#   Attempting uninstall: tensorflow━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [tensorboard]
#     Found existing installation: tensorflow 2.19.0━━━━━━━━━━━━ 2/5 [tensorboard]
#     Uninstalling tensorflow-2.19.0:m╺━━━━━━━━━━━━━━━ 3/5 [tensorflow]
#       Successfully uninstalled tensorflow-2.19.090m━━━━━━━━━━━━━━━ 3/5 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [tensorflow-macos][tensorflow]
# Successfully installed ml-dtypes-0.3.2 protobuf-4.25.8 tensorboard-2.16.2 tensorflow-2.16.2 tensorflow-macos-2.16.2
# Collecting tensorflow-metal
#   Downloading tensorflow_metal-1.2.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (1.3 kB)
# Requirement already satisfied: wheel~=0.35 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow-metal) (0.45.1)
# Requirement already satisfied: six>=1.15.0 in /Users/ramjeetdixit/MyEnv/lib/python3.11/site-packages (from tensorflow-metal) (1.17.0)
# Downloading tensorflow_metal-1.2.0-cp311-cp311-macosx_12_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.4 MB/s  0:00:00
# Installing collected packages: tensorflow-metal
# Successfully installed tensorflow-metal-1.2.0
